# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
response = requests.get('https://lifehacker.ru/topics/technology/')
response.text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU"><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Технологии — Лайфхакер</title>\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext-DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-latin-ext-CNk3-nEk.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:PT Root;font-style:nor ...

# %%
base_url = 'https://lifehacker.ru/topics/technology/'
response = requests.get('https://lifehacker.ru/topics/technology/') # получаем контент первой страницы
soup = BeautifulSoup(response.text, 'lxml') # инициализируем объект bs4 и задаем парсер lxml

# %%
soup.find_all('a', class_='lh-small-article-card__link') #ищем все a-элементы с классом lh-small-article-card__link
# Out:
# [<a aria-label="Microsoft внезапно закрыла свой магазин фильмов и телепередач на Xbox и Windows" class="lh-small-article-card__link" data-jest="link" href="/magazin-filmov-microsoft-zakryvaetsya/" title="Microsoft внезапно закрыла свой магазин фильмов и телепередач на Xbox и Windows"><!--[--><!--]--></a>,
#  <a aria-label="Инсайдеры раскрыли толщину и цену первого складного iPhone" class="lh-small-article-card__link" data-jest="link" href="/cena-skladnogo-iphone/" title="Инсайдеры раскрыли толщину и цену первого складного iPhone"><!--[--><!--]--></a>,
#  <a aria-label="Промпт дня: «дай мне прозвище» — чтобы ChatGPT раскрыл, что о вас думает" class="lh-small-article-card__link" data-jest="link" href="/prompt-dnya-dai-mne-prozvishhe/" title="Промпт дня: «дай мне прозвище» — чтобы ChatGPT раскрыл, что о вас думает"><!--[--><!--]--></a>,
#  <a aria-label="Samsung добавила эффект стекла в One UI — после насмешек над&amp;nbsp;Apple" class="lh-small-article-card__link" data-jest="link" href="/effekt-stekla-v-one-ui/" title="Samsung добавила эффект стекла в One UI — после насмешек над&amp;nbsp;Apple"><!--[--><!--]--></a>,
#  <a aria-label="OpenAI выпустила ChatGPT agent — помощника для выполнения задач на компьютере и в браузере" class="lh-small-article-card__link" data-jest="link" href="/predstavlen-chatgpt-agent/" title="OpenAI выпустила ChatGPT agent — помощника для выполнения задач на компьютере и в браузере"><!--[--><!--]--></a>,
#  <a aria-label="«Скидыщ!»: Adobe запустила ИИ-инструмент, который превращает любые звуки в реалистичные аудиоэффекты" class="lh-small-article-card__link" data-jest="link" href="/firefly-generaciya-zvukov-golosom/" title="«Скидыщ!»: Adobe запустила ИИ-инструмент, который превращает любые звуки в реалистичные аудиоэффекты"><!--[--><!--]--></a>,
#  <a aria-label="Представлен ноутбук LG Gram Pro с RTX 5050 и толщиной всего 1,5 сантиметра" class="lh-small-article-card__link" data-jest="link" href="/anons-lg-gram-pro-2025/" title="Представлен ноутбук LG Gram Pro с RTX 5050 и толщиной всего 1,5 сантиметра"><!--[--><!--]--></a>,
#  <a aria-label="Эстетично и практично: 7 способов спрятать провода от телевизора на&amp;nbsp;стене" class="lh-small-article-card__link" data-jest="link" href="/kak-spryatat-provoda-na-stene/" title="Эстетично и практично: 7 способов спрятать провода от телевизора на&amp;nbsp;стене"><!--[--><!--]--></a>,
#  <a aria-label="Google объявила дату презентации Pixel 10 и других новинок" class="lh-small-article-card__link" data-jest="link" href="/made-by-google-2025/" title="Google объявила дату презентации Pixel 10 и других новинок"><!--[--><!--]--></a>,
#  <a aria-label="В ChatGPT появились стили для изображений — больше не нужно придумывать промпты" class="lh-small-article-card__link" data-jest="link" href="/stili-izobrazhenii-v-chatgpt/" title="В ChatGPT появились стили для изображений — больше не нужно придумывать промпты"><!--[--><!--]--></a>,
#  <a aria-label="В линейке iPhone 17 будет только одна титановая модель — и это не Pro-версия" class="lh-small-article-card__link" data-jest="link" href="/titanovyi-iphone-17/" title="В линейке iPhone 17 будет только одна титановая модель — и это не Pro-версия"><!--[--><!--]--></a>,
#  <a aria-label="Обзор Perplexity — мощного ИИ-поисковика, который умеет проводить глубокие исследования" class="lh-small-article-card__link" data-jest="link" href="/perplexity-neiroset-onlain/" title="Обзор Perplexity — мощного ИИ-поисковика, который умеет проводить глубокие исследования"><!--[--><!--]--></a>,
#  <a aria-label="Ugreen представила первый в мире Qi2.2‑пауэрбанк — с 25-ваттной беспроводной зарядкой" class="lh-small-article-card__link" data-jest="link" href="/anons-ugreen-magflow/" title="Ugreen представила первый в мире Qi2.2‑пауэрбанк — с 25-ваттной беспроводной зарядкой"><!--[--><!--]--></a>,
#  <a aria-label="Honor показала игровой планшет Pad GT2 Pro с 8 динамиками и частотой экрана 165&amp;nbsp;Гц" class="lh-small-article-card__link" data-jest="link" href="/anons-honor-pad-gt2-pro/" title="Honor показала игровой планшет Pad GT2 Pro с 8 динамиками и частотой экрана 165&amp;nbsp;Гц"><!--[--><!--]--></a>,
#  <a aria-label="Form представила умные очки для плавания Smart Swim 2 с дополненной реальностью" class="lh-small-article-card__link" data-jest="link" href="/anons-form-smart-swim-2/" title="Form представила умные очки для плавания Smart Swim 2 с дополненной реальностью"><!--[--><!--]--></a>,
#  <a aria-label="Браузер Chrome перестанет поддерживаться на macOS Big Sur — уже в августе" class="lh-small-article-card__link" data-jest="link" href="/podderzhka-chrome-na-big-sur/" title="Браузер Chrome перестанет поддерживаться на macOS Big Sur — уже в августе"><!--[--><!--]--></a>,
#  <a aria-label="Объясняем за минуту: какую домашнюю технику стоит отключать на время отъезда" class="lh-small-article-card__link" data-jest="link" href="/otklyuchat-texniku-na-vremya-otezda/" title="Объясняем за минуту: какую домашнюю технику стоит отключать на время отъезда"><!--[--><!--]--></a>,
#  <a aria-label="Представлен сверхпрочный смартфон Honor X70 с рекордной батареей на 8 300 мА⋅ч" class="lh-small-article-card__link" data-jest="link" href="/anons-honor-x70/" title="Представлен сверхпрочный смартфон Honor X70 с рекордной батареей на 8 300 мА⋅ч"><!--[--><!--]--></a>,
#  <a aria-label="Мессенджер Max от VK стал национальным — теперь официально" class="lh-small-article-card__link" data-jest="link" href="/max-stal-nacionalnym/" title="Мессенджер Max от VK стал национальным — теперь официально"><!--[--><!--]--></a>,
#  <a aria-label="Аналитики&amp;nbsp;призвали Apple заменить Тима Кука — иначе ей грозит судьба BlackBerry и&amp;nbsp;Nokia" class="lh-small-article-card__link" data-jest="link" href="/zamena-tima-kuka/" title="Аналитики&amp;nbsp;призвали Apple заменить Тима Кука — иначе ей грозит судьба BlackBerry и&amp;nbsp;Nokia"><!--[--><!--]--></a>,
#  <a aria-label="Microsoft тестирует умное энергосбережение в Windows 11 — оно не снижает яркость экрана" class="lh-small-article-card__link" data-jest="link" href="/umnoe-energosberezhenie-v-windows-11/" title="Microsoft тестирует умное энергосбережение в Windows 11 — оно не снижает яркость экрана"><!--[--><!--]--></a>,
#  <a aria-label="ИИ станет умнее всех людей вместе взятых уже через 5 лет — Илон&amp;nbsp;Маск" class="lh-small-article-card__link" data-jest="link" href="/kogda-ii-stanet-umnee-vsex-lyudei/" title="ИИ станет умнее всех людей вместе взятых уже через 5 лет — Илон&amp;nbsp;Маск"><!--[--><!--]--></a>,
#  <a aria-label="В Office для Windows 10 перестанут появляться новые функции" class="lh-small-article-card__link" data-jest="link" href="/novye-funkcii-v-office-dlya-windows-10/" title="В Office для Windows 10 перестанут появляться новые функции"><!--[--><!--]--></a>,
#  <a aria-label="9 вещей, в которых не стоит доверять ChatGPT" class="lh-small-article-card__link" data-jest="link" href="/kogda-chatgpt-ploxoj-sovetchik/" title="9 вещей, в которых не стоит доверять ChatGPT"><!--[--><!--]--></a>,
#  <a aria-label="Создатель Twitter выпустил приложение Sun Day — для безопасного пребывания на солнце" class="lh-small-article-card__link" data-jest="link" href="/sun-day-ot-dorsi/" title="Создатель Twitter выпустил приложение Sun Day — для безопасного пребывания на солнце"><!--[--><!--]--></a>,
#  <a aria-label="Samsung может отказаться от Plus-версий своих смартфонов — вслед за&amp;nbsp;Apple" class="lh-small-article-card__link" data-jest="link" href="/samsung-mozhet-otkazatsya-ot-plus-versii-svoix-smartfonov/" title="Samsung может отказаться от Plus-версий своих смартфонов — вслед за&amp;nbsp;Apple"><!--[--><!--]--></a>,
#  <a aria-label="Чехлы для всей линейки iPhone 17 показали на фото — у каждого уникальный вырез под камеру" class="lh-small-article-card__link" data-jest="link" href="/chexly-iphone-17/" title="Чехлы для всей линейки iPhone 17 показали на фото — у каждого уникальный вырез под камеру"><!--[--><!--]--></a>,
#  <a aria-label="Лучшие гонки на Android: 14 крутых бесплатных игр на любой&amp;nbsp;вкус" class="lh-small-article-card__link" data-jest="link" href="/luchshie-gonki-na-android/" title="Лучшие гонки на Android: 14 крутых бесплатных игр на любой&amp;nbsp;вкус"><!--[--><!--]--></a>,
#  <a aria-label="OpenAI снова отложила выпуск своей открытой модели для «создания великих вещей»" class="lh-small-article-card__link" data-jest="link" href="/otkrytaya-model-openai/" title="OpenAI снова отложила выпуск своей открытой модели для «создания великих вещей»"><!--[--><!--]--></a>,
#  <a aria-label="Apple готовит масштабное обновление Dynamic Island в новых iPhone" class="lh-small-article-card__link" data-jest="link" href="/gryadet-evolyuciya-dynamic-island/" title="Apple готовит масштабное обновление Dynamic Island в новых iPhone"><!--[--><!--]--></a>]

# %%
from types import CellType
raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')  # ищем все a-элементы с классом lh-article-card-controls__comments
links = [item.get('href').replace('/#comments', '') for item in raw_items] # получаем у ссылок только href-атрибут, убираем подстроку '/comments'
links
# Out:
# ['/magazin-filmov-microsoft-zakryvaetsya',
#  '/cena-skladnogo-iphone',
#  '/prompt-dnya-dai-mne-prozvishhe',
#  '/effekt-stekla-v-one-ui',
#  '/predstavlen-chatgpt-agent',
#  '/firefly-generaciya-zvukov-golosom',
#  '/anons-lg-gram-pro-2025',
#  '/kak-spryatat-provoda-na-stene',
#  '/made-by-google-2025',
#  '/stili-izobrazhenii-v-chatgpt',
#  '/titanovyi-iphone-17',
#  '/perplexity-neiroset-onlain',
#  '/anons-ugreen-magflow',
#  '/anons-honor-pad-gt2-pro',
#  '/anons-form-smart-swim-2',
#  '/podderzhka-chrome-na-big-sur',
#  '/otklyuchat-texniku-na-vremya-otezda',
#  '/anons-honor-x70',
#  '/max-stal-nacionalnym',
#  '/zamena-tima-kuka',
#  '/umnoe-energosberezhenie-v-windows-11',
#  '/kogda-ii-stanet-umnee-vsex-lyudei',
#  '/novye-funkcii-v-office-dlya-windows-10',
#  '/kogda-chatgpt-ploxoj-sovetchik',
#  '/sun-day-ot-dorsi',
#  '/samsung-mozhet-otkazatsya-ot-plus-versii-svoix-smartfonov',
#  '/chexly-iphone-17',
#  '/luchshie-gonki-na-android',
#  '/otkrytaya-model-openai',
#  '/gryadet-evolyuciya-dynamic-island']

# %%
import requests
requests.get('https://lifehacker.ru/topics/technology/').text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU"><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Технологии — Лайфхакер</title>\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext-DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-latin-ext-CNk3-nEk.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:PT Root;font-style:nor ...

# %%
parsed_urls = []

# %%
for page_num in range(1, 11):
    url = f'{base_url}/?page={page_num}' # подставляем нужный номер страницы для пагинации, дальше парсим каждую страницу аналогично коду выше
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')
    parsed_urls += [item.get('href').replace('/#comments', '') for item in raw_items]

# %%
len(parsed_urls)

290

parsed_urls[35:45]
# Out:
# ['/firefly-generaciya-zvukov-golosom',
#  '/anons-lg-gram-pro-2025',
#  '/kak-spryatat-provoda-na-stene',
#  '/made-by-google-2025',
#  '/stili-izobrazhenii-v-chatgpt',
#  '/titanovyi-iphone-17',
#  '/perplexity-neiroset-onlain',
#  '/anons-ugreen-magflow',
#  '/anons-honor-pad-gt2-pro',
#  '/anons-form-smart-swim-2']

# %%
base_url = 'https://lifehacker.ru/'


response = requests.get('https://lifehacker.ru/kak-vybrat-saundbar/')
soup = BeautifulSoup(response.text, 'lxml')
soup.find('article', class_='single-article__post-content single-article__content-container').text
# Out:
# 'Саундбар — это компактная аудиосистема в едином корпусе. От обычных портативных колонок он отличается своей конструкцией и технологиями: имеет вытянутую форму и обеспечивает стереофоническое и даже объёмное звучание, несмотря на скромные размеры.Вариантов таких устройств много, и цены отличаются на порядок. Но смысл переплачивать есть далеко не всегда. Всё зависит от того, как и с чем вы планируете использовать саундбар. Вот несколько важных советов по выбору.\xa0Изучите возможности саундбараСаундбары сильно различаются по возможностям: одни будет едва слышно в 2–3 метрах, другие — могут «накрыть» звуком просторный зал. Вот на какие параметры обратить внимание.\xa0Номинальная мощность комплектаТут всё логично —\xa0чем выше мощность, тем громче\xa0звук:До 100 Вт — такие саундбары обеспечивают громкость, достаточную для небольших комнат, таких как спальни или кабинеты. Они подойдут для улучшения звука телевизора, компьютера или смартфона. Но не стоит ожидать мощных басов или объёмного звучания.\n100–300 Вт — саундбары в этом диапазоне мощности подходят для средних помещений, таких как гостиные. Они обеспечивают хороший баланс между громкостью и качеством звука, включая более выраженные басы и чёткость.\xa0\n300–400 Вт — эти устройства обеспечивают мощное и качественное звучание, подходящее для больших помещений или для любителей насыщенного и громкого звука. В них можно ожидать хорошие басы и объём, а также поддержку современных звуковых технологий, таких как Dolby Atmos. Они хорошо подходят для домашнего кинотеатра.\nОт 400 Вт — это премиальные устройства, которые могут заполнить большие помещения громким и детализированным звуком с мощными басами. Часто такие модели оснащены продвинутыми технологиями и дополнительными сабвуферами.\xa0\nЕсли саундбар укомплектован сабвуфером, то имейте в виду, что мощность сабвуфера должна быть примерно вдвое выше мощности самого саундбара. Только в этом случае при увеличении громкости не будет «провала» по нижним частотам.Устройства c разной мощностью:Саундбар Xiaomi Redmi Computer Speaker, 10 Вт от 4 022 рублей\xa0→\nСаундбар Xiaomi MI TV Soundbar 2.0, 84 Вт, от 7 250 рублей\xa0→\nСаундбар Hisense HS2100, 240 Вт, от 9 786 рублей\xa0→\nСаундбар Sony HT-S20R, 400 Вт, от 27 576 рублей\xa0→\nСаундбар Samsung HW-Q990F/RU 2025, 756 Вт, от 117 127 рублей\xa0→\nЗвуковая схемаЗвуковая схема саундбаров обозначается так же, как у других аудиосистем: X.Y.Z. Где, Х — количество каналов, а Y может иметь два значения — 0 и 1, они говорят о наличии сабвуфера. Z в обозначении звуковой схемы встречается нечасто и определяет количество потолочных каналов, ответственных за создание объёмного звука в форматах Dolby Atmos и DTS:X. Изображение: LGКаждый из компонентов схемы оказывает своё влияние на звуковую картину. Схемы могут быть следующими:2.0 — схема большинства бюджетных моделей, фактически представляющих собой пару небольших динамиков в одном корпусе. Качество звука соответствующее.\n2.1 — аналог стереосистемы с сабвуфером. Некоторые многополосные саундбары такой схемы уже могут обеспечить довольно качественный звук.\n3.1 — тот же саундбар с сабвуфером, но к двум боковым каналам добавляется ещё один — в центре. Это позволяет качественнее проигрывать звуковые дорожки фильмов формата Dolby Surround. Боковые каналы отвечают за воспроизведение окружающих звуков, а центральный — за диалоги героев.\n3.1.2 — применительно к саундбарам такая схема означает, что в корпусе установлены дополнительные динамики, направленные вверх. Отражение звуковых волн от потолка создаёт объёмный эффект.\n5.0 — саундбар с пятью раздельными каналами, которые могут быть объединены в одном корпусе. Хотя некоторые модели такой схемы имеют пару отдельных колонок, отвечающих за тыловые каналы.\xa0\n5.1 и 5.1.2 — мощные модели с сабвуфером. Оптимальный вариант для домашнего кинотеатра. Тыловые каналы могут реализовываться отдельными динамиками, а могут быть виртуальными, создаваемыми с помощью отражений звука от стен и потолка — в этом слу ...

# %%
soup.find('h1', class_='article-card__title').text
# Out:
# 'Как выбрать саундбар для телевизора, компьютера и смартфона'

# %%
result = []

for url in tqdm(parsed_urls):
    article = {}

    article_url = f'{base_url}{url}' # подставляем часть ссылки, ведущую материал
    response = requests.get(article_url)
    soup = BeautifulSoup(response.text, 'lxml')

    article['title'] = soup.find('h1', class_='article-card__title').text # Получаем текст из span в первом h1 с классом tm-title_h1
    article['text'] = soup.find('article', class_='single-article__post-content single-article__content-container').text # Получаем весь текст из div с классом tm-article-body
    votes_element = soup.find('span', class_='reactioncurrent-count')
    article['votes_count'] = votes_element.text.strip() if votes_element else 0


    result.append(article)
# Out:
# 100%|██████████| 300/300 [11:57<00:00,  2.39s/it]

# %%
pd.set_option('display.max_colwidth', 400)

# %%
data = pd.DataFrame(result)
data.head()
# Out:
#                                                                                         title  \
# 0             Microsoft внезапно закрыла свой магазин фильмов и телепередач на Xbox и Windows
# 1                                  Инсайдеры раскрыли толщину и цену первого складного iPhone
# 2                    Промпт дня: «дай мне прозвище» — чтобы ChatGPT раскрыл, что о вас думает
# 3                          Samsung добавила эффект стекла в One UI — после насмешек над Apple
# 4  OpenAI выпустила ChatGPT agent — помощника для выполнения задач на компьютере и в браузере
#
#                                                                                                                                                                                                                                                                                                                                                                                                               text  \
# 0  Microsoft официально прекратила поддержку своего магазина фильмов и телепередач на консолях Xbox и ПК с Windows. Приобретать видеоконтент через Microsoft Store больше нельзя.В компании отметили, что ранее загруженные материалы сохранятся в максимальном разрешении HD и останутся доступными. Однако их воспроизведение будет возможно только через закрытое приложение «Фильмы и ТВ-передачи», которое...
# 1  Складной iPhone от Apple будет стоить от 1 800 до 2 000 долларов (≈141 700–157 400 рублей, утверждают аналитики инвестиционно-банковской компании UBS. Если это подтвердится, он будет дороже MacBook Pro, который предлагается за 1 599 долларов (≈126 000 рублей).Устройство также станет самым дорогим телефоном в истории купертинцев, превзойдя текущий iPhone Pro Max, цена которого начинается с 1 19...
# 2  ChatGPT можно заставить проанализировать пользователя и дать ему короткое ёмкое прозвище благодаря функции памяти между переписками. Первым делом проверьте, включена ли она: в настройках выберите «Персонализация» и убедитесь, что переключатель у пункта «Ссылка на сохранённую память» в активном положении. Если это так, запустите новый чат и вбейте следующее:Ты — профессиональный, вдумчивый и пр...
# 3  Samsung, которая ещё недавно иронизировала по поводу нового «стеклянного» дизайна Liquid Glass в iOS 26, теперь позаимствовала эту идею для своего приложения Theme Park. В нём появился эффект Glass, превращающий домашний экран в полупрозрачную витрину. Главное отличие от решения Apple — максимальная гибкость и кастомизация.Обновление Theme Park под номером 1.1.01.23 вышло 18 июля и добавило ср...
# 4  OpenAI представила ИИ-агента с лаконичным названием — agent. Он находится прямо в интерфейсе ChatGPT и, по словам компании, может выполнять сложные задачи от имени пользователя.Инструмент сочетает в себе возможности ChatGPT, Operator и Deep Research. Он способен сёрфить в интернете, создавать исследовательские отчёты на базе десятков источников, делать презентации, писать код, оформлять онлайн...
#
#    votes_count
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
